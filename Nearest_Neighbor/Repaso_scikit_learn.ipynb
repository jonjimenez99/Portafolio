# %% [markdown]
# # This Notebook is created to follow the information of the [O'Reilly's course "Python applied for machine learning'](https://learning.oreilly.com/library/view/introduction-to-machine/9781449369880/ch01.html#installing-scikit-learn):

# %%
# Install libraries to install scikit-learn:
# !pip install numpy scipy matplotlib ipython scikit-learn pandas pillow

# %%
# %matplotlib inline

# %%
# Exercise:
# Create the graphic of the sin(x) function:
import numpy as np
import matplotlib.pyplot as plt

# Create a list from -10 to 10 filling with 100 values
x = np.linspace(0,100,1000)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %%
pip install mglearn #Library created by the writer of the book
# Out:
# ...
#   Obtaining dependency information for mglearn from https://files.pythonhosted.org/packages/bb/8b/687d30a3df6b870af541dde6327423e35713e38243db135f57b4ebd054f3/mglearn-0.2.0-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/581.4 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/581.4 kB 660.6 kB/s eta 0:00:01
#    -------------------------------- ------- 471.0/581.4 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 581.4/581.4 kB 6.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn
from IPython.display import display

# %%
import sys
print("Python version:", sys.version)

import pandas as pd
print("pandas version:", pd.__version__)

import matplotlib
print("matplotlib version:", matplotlib.__version__)

import numpy as np
print("NumPy version:", np.__version__)

import scipy as sp
print("SciPy version:", sp.__version__)

import IPython
print("IPython version:", IPython.__version__)

import sklearn
print("scikit-learn version:", sklearn.__version__)
# Out:
# Python version: 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
# pandas version: 2.0.3
# matplotlib version: 3.7.2
# NumPy version: 1.24.3
# SciPy version: 1.11.1
# IPython version: 8.15.0
# scikit-learn version: 1.3.0

# %%
# First use case:
# Classifying Iris Dataset:

from sklearn.datasets import load_iris
iris_dataset = load_iris()

# %%
print("Keys of iris_dataset:\n", iris_dataset.keys())
# Out:
# Keys of iris_dataset:
#  dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(iris_dataset['DESCR'][:190] + "\n...")
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric,

# %%
print(iris_dataset['DESCR'][:300])
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal w

# %%
print("Target names:", iris_dataset['target_names'])
# Out:
# Target names: ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# # Objective: Create a ML Model:
#
# First we will have to create the train and test sample:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state = 42, 
                                                    test_size=0.2)

# %%
print('El tamaño de Test, es: ', X_test.shape)
print('El tamaño de Train, es: ', X_train.shape)
# Out:
# El tamaño de Test, es:  (30, 4)
# El tamaño de Train, es:  (120, 4)
